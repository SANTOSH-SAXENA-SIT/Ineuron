# %%
import seaborn as sns
import plotly.express as ex
import cufflinks as clf
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.decomposition import PCA

# %%
iris  = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
clf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
iris["species"] == "setosa"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: species, Length: 150, dtype: bool

# %%
pca = PCA(n_components=3)

# %%
iris_plot = pca.fit_transform(iris.iloc[:,0:3])

# %%
iris_plot[:,1]
# Out:
# array([ 0.32097336, -0.17840062, -0.13782006, -0.31567523,  0.3313569 ,
#         0.75052335, -0.07294414,  0.16293168, -0.57231813, -0.12390824,
#         0.64153859,  0.01527354, -0.24232295, -0.50249413,  1.17958596,
#         1.35344664,  0.8297773 ,  0.32097336,  0.86798447,  0.52407748,
#         0.37899402,  0.44977161,  0.15492154,  0.11292117, -0.04416692,
#        -0.15410527,  0.1431182 ,  0.3650822 ,  0.31058983, -0.19726052,
#        -0.20764406,  0.41862099,  0.8109174 ,  1.09680374, -0.12390824,
#         0.07376041,  0.59647616,  0.26743457, -0.47819877,  0.22685401,
#         0.27686452, -0.93441751, -0.32958704,  0.21742406,  0.44482353,
#        -0.24232295,  0.50426399, -0.22155587,  0.57761626,  0.1084393 ,
#         0.65873491,  0.31482792,  0.48087974, -0.83015839,  0.06171329,
#        -0.42985184,  0.28558448, -1.00069208,  0.19994149, -0.70488842,
#        -1.27362019, -0.09395499, -0.58485262, -0.13948364, -0.24114692,
# ...

# %%
iris_plot = pd.DataFrame({"1st ":iris_plot[:,0], "2nd":iris_plot[:,1], "3rd":iris_plot[:,2]})

# %%
iris_plot["species"] = iris["species"]

# %%
iris_plot
# Out:
#          1st        2nd       3rd    species
# 0   -2.490880  0.320973 -0.033975     setosa
# 1   -2.523343 -0.178401 -0.232901     setosa
# 2   -2.711149 -0.137820 -0.002506     setosa
# 3   -2.557756 -0.315675  0.067051     setosa
# 4   -2.538964  0.331357  0.098615     setosa
# ..        ...       ...       ...        ...
# 145  1.660591  0.219289 -0.104298  virginica
# 146  1.366886 -0.368303 -0.240215  virginica
# 147  1.582625  0.091444  0.028280  virginica
# 148  1.612547  0.157274  0.561919  virginica
# 149  1.257087 -0.272276  0.391230  virginica
#
# [150 rows x 4 columns]

# %%
ex.scatter_3d(iris_plot, x = "1st ", y = "2nd", z = "3rd", color = "species")
# Out:
# <div>                            <div id="07f56c46-544c-4345-8215-df4d1f3134d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07f56c46-544c-4345-8215-df4d1f3134d2")) {                    Plotly.newPlot(                        "07f56c46-544c-4345-8215-df4d1f3134d2",                        [{"hovertemplate": "species=setosa<br>1st =%{x}<br>2nd=%{y}<br>3rd=%{z}<extra></extra>", "legendgroup": "setosa", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "setosa", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-2.490880176459122, -2.523342855807716, -2.71114887873848, -2.5577559512663006, -2.538964320653582, -2.1354201492905385, -2.6766960896825696, -2.429124983528788, -2.7091587690311627, -2.44080592255734
# ...

# %%
iris_plot
# Out:
#          1st        2nd       3rd    species
# 0   -2.490880  0.320973 -0.033975     setosa
# 1   -2.523343 -0.178401 -0.232901     setosa
# 2   -2.711149 -0.137820 -0.002506     setosa
# 3   -2.557756 -0.315675  0.067051     setosa
# 4   -2.538964  0.331357  0.098615     setosa
# ..        ...       ...       ...        ...
# 145  1.660591  0.219289 -0.104298  virginica
# 146  1.366886 -0.368303 -0.240215  virginica
# 147  1.582625  0.091444  0.028280  virginica
# 148  1.612547  0.157274  0.561919  virginica
# 149  1.257087 -0.272276  0.391230  virginica
#
# [150 rows x 4 columns]

# %%
ex.scatter_3d(iris, x = "sepal_length", y = "sepal_width", z = "petal_length", color = "species")
# Out:
# <div>                            <div id="2b014732-50d4-48c7-b5e2-0598fbaa84b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b014732-50d4-48c7-b5e2-0598fbaa84b2")) {                    Plotly.newPlot(                        "2b014732-50d4-48c7-b5e2-0598fbaa84b2",                        [{"hovertemplate": "species=setosa<br>sepal_length=%{x}<br>sepal_width=%{y}<br>petal_length=%{z}<extra></extra>", "legendgroup": "setosa", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "setosa", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9, 5.4, 4.8, 4.8, 4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5.0, 5.0, 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 
# ...

# %%
iplot.plot.scatter3d()
